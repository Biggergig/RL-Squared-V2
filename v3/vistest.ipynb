# %%
import time
import numpy as np
import rlgym_sim

TPS = 120 / 8

from utils import build_rocketsim_env

env = build_rocketsim_env(name="visgym", phase=1)

# %%
obs = env.reset()
# obs

# %%
env._match.agents
# Out:
# 2

# %%
action = env.action_space.sample()
action
# Out:
# array([2, 1, 1, 2, 0, 0, 1, 0], dtype=int64)

# %%
# double the length of action:
baction = np.vstack([action, action])
# baction = np.concatenate([action, action])
print(baction)
# Out:
# [[2 1 1 2 0 0 1 0]
#  [2 1 1 2 0 0 1 0]]

# %%
env.step(baction)
# Out:
# ([array([-3.01049680e-01, -6.42075358e-01,  4.07362876e-01,  2.84537852e-01,
#          -6.26435354e-02, -2.55741388e-01,  1.40034243e-01,  2.93554336e-01,
#          -3.63054425e-01,  1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00, -1.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#           0.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  5.27747929e-01,
#          -6.36279622e-01,  8.30915156e-03,  2.15039551e-01,  9.76560593e-01,
#          -9.34833288e-03,  1.93632743e-03,  9.14591178e-03,  9.99956310e-01,
#           1.09478123e-01,  3.56491894e-01,  8.89110161e-05, -1.94558944e-03,
#           7.78683228e-04,  5.00347558e-03,  6.06430740e-01,  1.00000000e+00,
#           1.00000000e+00,  0.00000000e+00,  6.61676407e-01,  5.41288737e-01,
#           1.87156364e-01,  3.41011167e-01,  9.33310091e-01, -1.12443455e-01,
#          -9.32589918e-02,  1.52610376e-01,  9.83876407e-01,  3.77636969e-01,
#          -3.43858153e-01,  2.51668960e-01,  5.54885864e-01,  6.21701300e-01,
#           5.52801251e-01,  4.04849243e-02,  0.00000000e+00,  1.00000000e+00,
#           0.00000000e+00]),
#   array([ 3.01049680e-01,  6.42075358e-01,  4.07362876e-01, -2.84537852e-01,
#           6.26435354e-02, -2.55741388e-01, -1.40034243e-01, -2.93554336e-01,
#          -3.63054425e-01,  1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00, -1.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#           0.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#           1.00000000e+00,  1.00000000e+00,  1.00000000e+00, -6.61676407e-01,
#          -5.41288737e-01,  1.87156364e-01, -3.41011167e-01, -9.33310091e-01,
#          -1.12443455e-01,  9.32589918e-02, -1.52610376e-01,  9.83876407e-01,
#          -3.77636969e-01,  3.43858153e-01,  2.51668960e-01, -5.54885864e-01,
#          -6.21701300e-01,  5.52801251e-01,  4.04849243e-02,  0.00000000e+00,
#           1.00000000e+00,  0.00000000e+00, -5.27747929e-01,  6.36279622e-01,
#           8.30915156e-03, -2.15039551e-01, -9.76560593e-01, -9.34833288e-03,
#          -1.93632743e-03, -9.14591178e-03,  9.99956310e-01, -1.09478123e-01,
#          -3.56491894e-01,  8.89110161e-05,  1.94558944e-03, -7.78683228e-04,
#           5.00347558e-03,  6.06430740e-01,  1.00000000e+00,  1.00000000e+00,
#           0.00000000e+00])],
#  [-3.7292347783627715, -5.6937277088994565],
#  False,
#  {'state': <rlgym_sim.utils.gamestates.game_state.GameState at 0x191f19c76a0>,
#   'result': 0.0})
